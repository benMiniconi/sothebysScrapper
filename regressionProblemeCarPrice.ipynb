# %% [markdown]
# <a href="https://colab.research.google.com/github/benMiniconi/sothebysScrapper/blob/master/regressionProblemeCarPrice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
carsData = pd.read_csv("./CarModel/AutoAnalysisModel.csv", sep=";")
carsData2000 = pd.read_csv("./CarModel/AutoAnalysisModel2000.csv", sep=";")

# %%
#EntireBase
carsData.tail(5)
# Out:
#         CleanerCylindree   Age                          UniqDetail  Price  \
# 244582             4.244  16.0  20990101000quattroporte2004berline  20990
# 244583             4.244  16.0  20990101000quattroporte2004berline  20990
# 244584             4.244  16.0  20990101000quattroporte2004berline  20990
# 244585             4.244  16.0   2100098500quattroporte2004berline  21000
# 244586             4.244  16.0  21500140000quattroporte2004berline  21500
#
#              Immat        KM  Power        modele    marque       annee  ...  \
# 244582  01/07/2004  101000.0  400.0  quattroporte  maserati  01/01/2004  ...
# 244583  01/07/2004  101000.0  400.0  quattroporte  maserati  01/01/2004  ...
# 244584  01/07/2004  101000.0  400.0  quattroporte  maserati  01/01/2004  ...
# 244585  01/12/2004   98500.0  400.0  quattroporte  maserati  01/01/2004  ...
# 244586  01/11/2004  140000.0  400.0  quattroporte  maserati  01/01/2004  ...
#
# ...

# %%
#EntireBase
carsData2000.tail(5)
# Out:
#         CleanerCylindree  Age                    UniqDetail   Price  \
# 117488             4.307   15  10390050000f4302005cabriolet  103900
# 117489             4.307   15  10500055390f4302005cabriolet  105000
# 117490             4.307   15      10500049600f4302005coupe  105000
# 117491             4.307   15      11000028747f4302005coupe  110000
# 117492             5.748   15       110000162006122005coupe  110000
#
#              Immat     KM  Power modele   marque       annee  ...  \
# 117488  01/11/2005  50000    489   f430  ferrari  01/01/2005  ...
# 117489  01/09/2005  55390    489   f430  ferrari  01/01/2005  ...
# 117490  01/05/2005  49600    489   f430  ferrari  01/01/2005  ...
# 117491  01/03/2005  28747    489   f430  ferrari  01/01/2005  ...
# 117492  01/04/2005  16200    540    612  ferrari  01/01/2005  ...
#
#        typedepeinture  couleuroriginale versionpays interieur 1 carrosserie  \
# 117488            uni             rosso         NaN    cuirnoir   cabriolet
# ...

# %%
sns.pairplot(carsData2000)

# %%
#Dropping unused Columns
X = carsData2000.drop(["Price", "sieges", "portes", "UniqDetail", "interieur 1", "typedepeinture", "couleuroriginale", "interieur"], axis=1)

# %%
X.head(5)
# Out:
#    CleanerCylindree  Age       Immat    KM  Power  modele     marque  \
# 0             2.891    5  01/07/2015  1950    510  giulia  alfaromeo
# 1             2.891    5  01/07/2015  1950    510  giulia  alfaromeo
# 2             2.891    5  01/07/2015  1950    510  giulia  alfaromeo
# 3             2.891    5  01/07/2015  1950    510  giulia  alfaromeo
# 4             2.891    5  01/07/2015  1950    510  giulia  alfaromeo
#
#         annee couleurexterieure couleurexterieure 1 versionpays carrosserie  \
# 0  01/01/2015             rouge               rouge      italie     berline
# 1  01/01/2015             rouge               rouge      italie     berline
# 2  01/01/2015             rouge               rouge      italie     berline
# 3  01/01/2015             rouge               rouge      italie     berline
# 4  01/01/2015             rouge               rouge      italie     berline
#
#   cylindree   transmission          File Paths
# ...
